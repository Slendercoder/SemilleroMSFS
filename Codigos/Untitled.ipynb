# %%
import pandas as pd

# %%
names=['Identificador','Numero_agentes','Tipo_red','Agente','Ronda','Estado','Puntaje','Politica','Parametro-0','Parametro-1']
data = pd.read_csv('./data/simulaciones-GRG-100-5.csv', names=names, header=None)
data.head()
# Out:
#    Identificador  Numero_agentes Tipo_red  Agente  Ronda  Estado  Puntaje  \
# 0           2700             100      GRG       0      0       1        1
# 1           2700             100      GRG       0     10       0        0
# 2           2700             100      GRG       0     20       0        0
# 3           2700             100      GRG       0     30       0        0
# 4           2700             100      GRG       0     40       0        0
#
#    Politica  Parametro-0  Parametro-1
# 0         0          100          0.5
# 1         3          100          0.5
# 2         3          100          0.5
# 3         3          100          0.5
# 4         3          100          0.5

# %%
data['P']

# %%
data[(data['Politica']==7) & (data['Ronda']!=0)]['Puntaje'].value_counts()
# Out:
# -1    6769
#  1    1036
#  0     558
# Name: Puntaje, dtype: int64

# %%
data[(data['Politica']==7) & (data['Ronda']!=0) & (data['Puntaje']==0)]
# Out:
#        Identificador  Numero_agentes Tipo_red  Agente  Ronda  Estado  Puntaje  \
# 2001            2702             100      GRG       0     10       0        0
# 2021            2702             100      GRG       2     10       0        0
# 2041            2702             100      GRG       4     10       0        0
# 2071            2702             100      GRG       7     10       0        0
# 2081            2702             100      GRG       8     10       0        0
# ...              ...             ...      ...     ...    ...     ...      ...
# 85991           2785             100      GRG      99     10       0        0
# 85993           2785             100      GRG      99     30       0        0
# 85995           2785             100      GRG      99     50       0        0
# 85997           2785             100      GRG      99     70       0        0
# 85999           2785             100      GRG      99     90       0        0
#
# ...
